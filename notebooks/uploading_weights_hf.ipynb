# %%
from huggingface_hub import create_repo
from huggingface_hub import upload_folder

# %%
create_repo("gbasi18/MoR-Vision-19500-RGB")
# Out:
# RepoUrl('https://huggingface.co/gbasi18/MoR-Vision-19500-RGB', endpoint='https://huggingface.co', repo_type='model', repo_id='gbasi18/MoR-Vision-19500-RGB')

# %%
upload_folder(
    repo_id="gbasi18/MoR-Vision-19500-RGB",
    folder_path="/home/gianfranco/projects/2025/Visual_Intelligence_Project/Mixture-of-Recursions-for-Vision/results/pretrain/251020_pretrain_smollm-135m_rec3_middle_cycle_random_lr3e-3_mor_expert_linear_alpha_0.1_sigmoid_aux_loss_0.001_clevr_rgb_19500/checkpoint-19500")
# Out:
# Processing Files (5 / 5): 100%|██████████| 1.17GB / 1.17GB, 14.5MB/s
# New Data Upload: 100%|██████████| 1.17GB / 1.17GB, 14.5MB/s
# CommitInfo(commit_url='https://huggingface.co/gbasi18/MoR-Vision-19500-RGB/commit/1427ad604c7b061b4b1a6389f170a28a5a790bf3', commit_message='Upload folder using huggingface_hub', commit_description='', oid='1427ad604c7b061b4b1a6389f170a28a5a790bf3', pr_url=None, repo_url=RepoUrl('https://huggingface.co/gbasi18/MoR-Vision-19500-RGB', endpoint='https://huggingface.co', repo_type='model', repo_id='gbasi18/MoR-Vision-19500-RGB'), pr_revision=None, pr_num=None)
